# %%
from deltalake import DeltaTable
import pandas as pd
from deltalake.writer import write_deltalake
import numpy as np

# %%
# Delta table path 
delta_table_path = f"abfss://<gold>@<pbkstdlprodne001>.dfs.core.windows.net//gold//engine_autocoding//engine_autocoding_base//000//delta//"

# ADLS storage account name and key 
storage_options = {"azure_storage_account_name": "pbkstdldevne001", "azure_storage_access_key": "9TuuZFsHSZ3uoNw9MR9dT1OnLRondqPKzlUscH94dhnE0+QoE0l9Js0M+aB+kNKHWj6R/GkNiLLz+AStRxzL9w=="}

# %%
# Define delta table 
dt = DeltaTable(delta_table_path, storage_options=storage_options)
dt.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# TableNotFoundError                        Traceback (most recent call last)
# c:\Users\StevenDas\Documents\RUSTApi\Read API\readAPI.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/StevenDas/Documents/RUSTApi/Read%20API/readAPI.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Define delta table
# ----> <a href='vscode-notebook-cell:/c%3A/Users/StevenDas/Documents/RUSTApi/Read%20API/readAPI.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> dt = DeltaTable(delta_table_path, storage_options=storage_options)
#       <a href='vscode-notebook-cell:/c%3A/Users/StevenDas/Documents/RUSTApi/Read%20API/readAPI.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> dt.to_pandas()
#
# File c:\Users\StevenDas\AppData\Local\Programs\Python\Python311\Lib\site-packages\deltalake\table.py:246, in DeltaTable.__init__(self, table_uri, version, storage_options, without_files, log_buffer_size)
#     227 """
#     228 Create the Delta Table from a path with an optional version.
#     229 Multiple StorageBackends are currently supported: AWS S3, Azure Data Lake Storage Gen2, Google Cloud Storage (GCS) and local URI.
#    (...)
#     243
#     244 """
#     245 self._storage_options = storage_options
# --> 246 self._table = RawDeltaTable(
#     247     str(table_uri),
#     248     version=version,
#     249     storage_options=storage_options,
#     250     without_files=without_files,
#     251     log_buffer_size=log_buffer_size,
#     252 )
#     253 self._metadata = Metadata(self._table)
#
# TableNotFoundError: Could not create local directory: abfss://<gold>@<pbkstdlprodne001>.dfs.core.windows.net//gold//engine_autocoding//engine_autocoding_base//000//delta//
# Error: Os { code: 123, kind: InvalidFilename, message: "The filename, directory name, or volume label syntax is incorrect." }

# %%
local_delta_table_path = "C:\\Users\\StevenDas\\Downloads\\EAC_Gold\\engine_autocoding_base\\000\\delta"
df = DeltaTable(local_delta_table_path)

# %%
# Check version of Delta table
print(df.version())

# Check files from Delta tables
print(df.files())
# Out:
# 89
# ['part-00000-33111a53-bc6a-4b36-a654-33d11a8b33ab-c000.snappy.parquet', 'part-00001-7a5395d6-128e-4fd6-b46a-e401cf41d1e5-c000.snappy.parquet', 'part-00002-43ab85ed-28a5-4a17-984c-40b46c5069b8-c000.snappy.parquet', 'part-00003-b8207d6b-68aa-49c3-bc37-0a6c6f81d73f-c000.snappy.parquet', 'part-00000-d8aa51e9-55ad-4a93-a9f9-b9fe820f6d86-c000.snappy.parquet', 'part-00001-1668fb9c-0f51-4bb7-b37b-74e7b2dca503-c000.snappy.parquet', 'part-00002-e832c5ae-155d-4fc5-b490-bb5fb5338272-c000.snappy.parquet', 'part-00003-17f002cc-4916-4c76-bcd8-c57186e13dab-c000.snappy.parquet']

# %%
# Convert to Pandas df
pandas_df = df.to_pandas()
pandas_df.dtypes
# Out:
# Depot                                          object
# R2_Depot                                       object
# TOC                                            object
# Railway_Period                                 object
# Date_Reported                                  object
# Date_Completed                                 object
# Date                                           object
# Fleet_Name                                     object
# Vehicle_Class                                  object
# Vehicle_Sub_Class                              object
# Unit                                           object
# Vehicle                                        object
# Intervention_ID                                object
# Intervention_Type                              object
# Intervention_Key                               object
# Component_Mileage                             float32
# Is_TIN                                           bool
# Intervention_Report                            object
# Intervention_Action                            object
# Work_Order_Type                                object
# Work_Order_Equipment                           object
# Work_Order_Status                              object
# System_Primary_Code                            object
# System_Primary_Code_Desc                       object
# System_Secondary_Code                          object
# System_Secondary_Code_Desc                     object
# Priority                                       object
# Warranty                                       object
# Location                                       object
# Sum_Prim_Delay_Mins                           float64
# Sum_Reactnry_Delay_Mins                       float64
# Sum_Total_Delay_Mins                          float64
# Count_Full_Cancellations                      float64
# Count_Part_Cancellations                      float64
# Count_Total_Cancellations                     float32
# Porterbrook_Asset                                bool
# Is_Autocoded                                     bool
# Date_Autocoded                                 object
# P_Symptom_Inferred                             object
# Root_Code_Secondary_Probability               float32
# Root_Code_Tertiary_Probability                float32
# Symptom_Code_Probability                      float32
# P_Symptom_Verified                             object
# P_Root_Code_Inferred_Secondary                 object
# P_Root_Code_Inferred_Secondary_Desc            object
# P_Root_Code_Inferred_Tertiary                  object
# P_Root_Code_Inferred_Tertiary_Desc             object
# P_Symptom_Code_Inferred                        object
# P_Symptom_Code_Inferred_Desc                   object
# P_Root_Code_Verified                           object
# P_Root_Code_Verified_Desc                      object
# Is_Verified                                      bool
# Date_Verified                                  object
# Master_Intervention_Key                        object
# Is_Relevant                                    object
# Is_Power_Pack_Intervention                       bool
# Model_URI_Root_Code_Secondary                  object
# Model_URI_Root_Code_Tertiary                   object
# Model_URI_Symptom                              object
# _Data_Source                                   object
# _Time_Added                            datetime64[ns]
# _Ingest_Timestamp                      datetime64[ns]
# _UID                                           object
# dtype: object

# %%
pandas_df
# Out:
#        Depot   R2_Depot    TOC Railway_Period Date_Reported Date_Completed  \
# 0       None  SALISBURY    SWR         23  P4          None     2022-07-05
# 1       None    TYSELEY    WMT         21  P3          None     2020-06-02
# 2       None    TYSELEY    WMT         21  P3          None     2020-06-18
# 3       None    TYSELEY    WMT         21  P4          None     2020-07-01
# 4       None    TYSELEY    WMT         21  P4          None     2020-07-07
# ...      ...        ...    ...            ...           ...            ...
# 196206  None  AYLESBURY  CHILT         24  P7    2023-09-18     2023-09-21
# 196207  None  AYLESBURY  CHILT         24  P7    2023-09-18     2023-09-18
# 196208  None  AYLESBURY  CHILT         24  P7    2023-09-19     2023-09-20
# 196209  None  AYLESBURY  CHILT         24  P7    2023-09-19           None
# 196210  None  AYLESBURY  CHILT         24  P7    2023-09-22           None
#
#               Date  Fleet_Name Vehicle_Class Vehicle_Sub_Class  ...  \
# 0       2022-07-05    SWT~1591           159              1591  ...
# 1       2020-06-02   LMID~1723           172              1723  ...
# 2       2020-06-18   LMID~1723           172              1723  ...
# 3       2020-07-01   LMID~1722           172              1722  ...
# 4       2020-07-07   LMID~1723           172              1723  ...
# ...            ...         ...           ...               ...  ...
# 196206  2023-09-18  CHILT~1680           168              1680  ...
# 196207  2023-09-18  CHILT~1683           168              1683  ...
# 196208  2023-09-19  CHILT~1682           168              1682  ...
# 196209  2023-09-19  CHILT~1680           168              1680  ...
# 196210  2023-09-22  CHILT~1680           168              1680  ...
#
#                      Master_Intervention_Key Is_Relevant  \
# 0       Third Party Maintenance-SWR-00000031        True
# 1                                       None        True
# 2                                       None        True
# 3                                       None        True
# 4                                       None        True
# ...                                      ...         ...
# 196206                                  None        True
# 196207                                  None        True
# 196208                                  None        True
# 196209                                  None        True
# 196210                                  None        True
#
#        Is_Power_Pack_Intervention           Model_URI_Root_Code_Secondary  \
# 0                            True  runs:/d76635f9b0f24646befbacf5c26f4dfa
# 1                           False                                    None
# 2                           False                                    None
# 3                           False                                    None
# 4                           False                                    None
# ...                           ...                                     ...
# 196206                       True  runs:/d76635f9b0f24646befbacf5c26f4dfa
# 196207                       True  runs:/d76635f9b0f24646befbacf5c26f4dfa
# 196208                       True  runs:/d76635f9b0f24646befbacf5c26f4dfa
# 196209                       True  runs:/d76635f9b0f24646befbacf5c26f4dfa
# 196210                       True  runs:/d76635f9b0f24646befbacf5c26f4dfa
#
#                   Model_URI_Root_Code_Tertiary  \
# 0       runs:/45f797cc09d442778aaf1f53812008da
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# ...                                        ...
# 196206  runs:/45f797cc09d442778aaf1f53812008da
# 196207  runs:/45f797cc09d442778aaf1f53812008da
# 196208  runs:/45f797cc09d442778aaf1f53812008da
# 196209  runs:/45f797cc09d442778aaf1f53812008da
# 196210  runs:/45f797cc09d442778aaf1f53812008da
#
#                              Model_URI_Symptom  \
# 0       runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# ...                                        ...
# 196206  runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
# 196207  runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
# 196208  runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
# 196209  runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
# 196210  runs:/1b01c76bb3c14b2b87e0ac109bfa1bbf
#
#                                              _Data_Source  \
# 0       dbfs:/mnt/landing/maintenance/third_party/000/...
# 1       dbfs:/mnt/landing/maintenance/third_party/000/...
# 2       dbfs:/mnt/landing/maintenance/third_party/000/...
# 3       dbfs:/mnt/landing/maintenance/third_party/000/...
# 4       dbfs:/mnt/landing/maintenance/third_party/000/...
# ...                                                   ...
# 196206  dbfs:/mnt/landing/maintenance/unplanned/CHILT/...
# 196207  dbfs:/mnt/landing/maintenance/unplanned/CHILT/...
# 196208  dbfs:/mnt/landing/maintenance/unplanned/CHILT/...
# 196209  dbfs:/mnt/landing/maintenance/unplanned/CHILT/...
# 196210  dbfs:/mnt/landing/maintenance/unplanned/CHILT/...
#
#                       _Time_Added          _Ingest_Timestamp  \
# 0      2023-09-24 12:07:27.424277 2023-04-15 08:05:39.009544
# 1      2023-09-24 12:07:27.424277 2023-07-20 21:20:43.478468
# 2      2023-09-24 12:07:27.424277 2023-07-20 21:20:43.478468
# 3      2023-09-24 12:07:27.424277 2023-07-20 21:20:43.478468
# 4      2023-09-24 12:07:27.424277 2023-04-15 08:05:39.009544
# ...                           ...                        ...
# 196206 2023-09-24 12:07:28.390400 2023-09-21 08:07:08.713384
# 196207 2023-09-24 12:07:28.390400 2023-09-19 08:08:27.243512
# 196208 2023-09-24 12:07:28.390400 2023-09-20 08:08:43.581623
# 196209 2023-09-24 12:07:28.390400 2023-09-20 08:08:43.581623
# 196210 2023-09-24 12:07:28.390400 2023-09-23 08:07:12.962886
#
#                                             _UID
# 0       4b68c317478005c16a8fe04c6c7dff04c2c194a9
# 1       9ad46d2dfc9069406f6b95bdf7861ff7678cec1f
# 2       5c4a2971f955acaef8ebf41c1cafa54a2349c498
# 3       adbfed6eeba32a43b174af2e1ef28e81e0cfa959
# 4       5778bf628a6c5bfcb5c411c37b39192dd179ad99
# ...                                          ...
# 196206  b1c426bd74dfda4f2a87f1f92f4f2281f72209fa
# 196207  bfee70fc37d932898336ef5f25cdb8a78b92d96e
# 196208  8dd3487b5c7c8db79ab9ac6a7f248d32ea5560e7
# 196209  f3681142ae7265e8dda4ba948a5e71bc203ac936
# 196210  e1f8a159165f713575e375da599b07a8a88ef858
#
# [196211 rows x 63 columns]

# %%
mock_data = {
    "Depot": ["Depot1"],
    "R2_Depot": ["R2_Depot1"],
    "TOC": ["TOC1"],
    "Railway_Period": ["Period1"],
    "Date_Reported": ["2023-09-25"],
    "Date_Completed": ["2023-09-26"],
    "Date": ["2023-09-25"],
    "Fleet_Name": ["Fleet1"],
    "Vehicle_Class": ["Class1"],
    "Vehicle_Sub_Class": ["SubClass1"],
    "Unit": ["Unit1"],
    "Vehicle": ["Vehicle1"],
    "Intervention_ID": ["Intervention1"],
    "Intervention_Type": ["Type1"],
    "Intervention_Key": ["Key1"],
    "Component_Mileage": [1000],
    "Is_TIN": [True],
    "Intervention_Report": ["Report1"],
    "Intervention_Action": ["Action1"],
    "Work_Order_Type": ["WorkOrderType1"],
    "Work_Order_Equipment": ["Equipment1"],
    "Work_Order_Status": ["Status1"],
    "System_Primary_Code": ["PrimaryCode1"],
    "System_Primary_Code_Desc": ["PrimaryCodeDesc1"],
    "System_Secondary_Code": ["SecondaryCode1"],
    "System_Secondary_Code_Desc": ["SecondaryCodeDesc1"],
    "Priority": ["Priority1"],
    "Warranty": ["Warranty1"],
    "Location": ["Location1"],
    "Sum_Prim_Delay_Mins": [30],
    "Sum_Reactnry_Delay_Mins": [15],
    "Sum_Total_Delay_Mins": [45],
    "Count_Full_Cancellations": [2],
    "Count_Part_Cancellations": [1],
    "Count_Total_Cancellations": [3.0],
    "Porterbrook_Asset": [False],
    "Is_Autocoded": [True],
    "Date_Autocoded": ["2023-09-25"],
    "P_Symptom_Inferred": ["Symptom1"],
    "Root_Code_Secondary_Probability": [0.8],
    "Root_Code_Tertiary_Probability": [0.6],
    "Symptom_Code_Probability": [0.7],
    "P_Symptom_Verified": ["SymptomVerified1"],
    "P_Root_Code_Inferred_Secondary": ["RootCodeInferredSecondary1"],
    "P_Root_Code_Inferred_Secondary_Desc": ["RootCodeInferredSecondaryDesc1"],
    "P_Root_Code_Inferred_Tertiary": ["RootCodeInferredTertiary1"],
    "P_Root_Code_Inferred_Tertiary_Desc": ["RootCodeInferredTertiaryDesc1"],
    "P_Symptom_Code_Inferred": ["SymptomCodeInferred1"],
    "P_Symptom_Code_Inferred_Desc": ["SymptomCodeInferredDesc1"],
    "P_Root_Code_Verified": ["RootCodeVerified1"],
    "P_Root_Code_Verified_Desc": ["RootCodeVerifiedDesc1"],
    "Is_Verified": [False],
    "Date_Verified": ["2023-09-26"],
    "Master_Intervention_Key": ["MasterInterventionKey1"],
    "Is_Relevant": [True],
    "Is_Power_Pack_Intervention": [False],
    "Model_URI_Root_Code_Secondary": ["ModelURIRootCodeSecondary1"],
    "Model_URI_Root_Code_Tertiary": ["ModelURIRootCodeTertiary1"],
    "Model_URI_Symptom": ["ModelURISymptom1"],
    "_Data_Source": ["DataSource1"],
    "_Time_Added": ["2023-09-25T12:00:00"],
    "_Ingest_Timestamp": ["2023-09-25T12:30:00"],
    "_UID": ["UID1"]
    }

mock_data_schema = {
    "Depot" : "object",
    "R2_Depot": "object",
    "TOC": "object",
    "Railway_Period": "object",
    "Date_Reported": "object",
    "Date_Completed": "object",
    "Date": "object",
    "Fleet_Name": "object",
    "Vehicle_Class": "object",
    "Vehicle_Sub_Class": "object",
    "Unit": "object",
    "Vehicle": "object",
    "Intervention_ID": "object",
    "Intervention_Type": "object",
    "Intervention_Key": "object",
    "Component_Mileage": "float32",
    "Is_TIN": "bool",
    "Intervention_Report": "object",
    "Intervention_Action": "object",
    "Work_Order_Type": "object",
    "Work_Order_Equipment": "object",
    "Work_Order_Status": "object",
    "System_Primary_Code": "object",
    "System_Primary_Code_Desc": "object",
    "System_Secondary_Code": "object",
    "System_Secondary_Code_Desc": "object",
    "Priority": "object",
    "Warranty": "object",
    "Location": "object",
    "Sum_Prim_Delay_Mins": "float64",
    "Sum_Reactnry_Delay_Mins": "float64",
    "Sum_Total_Delay_Mins": "float64",
    "Count_Full_Cancellations": "float64",
    "Count_Part_Cancellations": "float64",
    "Count_Total_Cancellations": "float32",
    "Porterbrook_Asset": "bool",
    "Is_Autocoded": "bool",
    "Date_Autocoded": "object",
    "P_Symptom_Inferred": "object",
    "Root_Code_Secondary_Probability": "float32",
    "Root_Code_Tertiary_Probability": "float32",
    "Symptom_Code_Probability": "float32",
    "P_Symptom_Verified": "object",
    "P_Root_Code_Inferred_Secondary": "object",
    "P_Root_Code_Inferred_Secondary_Desc": "object",
    "P_Root_Code_Inferred_Tertiary": "object",
    "P_Root_Code_Inferred_Tertiary_Desc": "object",
    "P_Symptom_Code_Inferred": "object",
    "P_Symptom_Code_Inferred_Desc": "object",
    "P_Root_Code_Verified": "object",
    "P_Root_Code_Verified_Desc": "object",
    "Is_Verified": "bool",
    "Date_Verified": "object",
    "Master_Intervention_Key": "object",
    "Is_Relevant": "object",
    "Is_Power_Pack_Intervention": "bool",
    "Model_URI_Root_Code_Secondary": "object",
    "Model_URI_Root_Code_Tertiary": "object",
    "Model_URI_Symptom": "object",
    "_Data_Source": "object",
    "_Time_Added": "datetime64[ns]",
    "_Ingest_Timestamp": "datetime64[ns]",
    "_UID": "object"
    }

# Create a Pandas DataFrame from the mock data
mock_df = pd.DataFrame(mock_data, dtype=object)

mock_df.dtypes
# Out:
# Depot                                  object
# R2_Depot                               object
# TOC                                    object
# Railway_Period                         object
# Date_Reported                          object
# Date_Completed                         object
# Date                                   object
# Fleet_Name                             object
# Vehicle_Class                          object
# Vehicle_Sub_Class                      object
# Unit                                   object
# Vehicle                                object
# Intervention_ID                        object
# Intervention_Type                      object
# Intervention_Key                       object
# Component_Mileage                      object
# Is_TIN                                 object
# Intervention_Report                    object
# Intervention_Action                    object
# Work_Order_Type                        object
# Work_Order_Equipment                   object
# Work_Order_Status                      object
# System_Primary_Code                    object
# System_Primary_Code_Desc               object
# System_Secondary_Code                  object
# System_Secondary_Code_Desc             object
# Priority                               object
# Warranty                               object
# Location                               object
# Sum_Prim_Delay_Mins                    object
# Sum_Reactnry_Delay_Mins                object
# Sum_Total_Delay_Mins                   object
# Count_Full_Cancellations               object
# Count_Part_Cancellations               object
# Count_Total_Cancellations              object
# Porterbrook_Asset                      object
# Is_Autocoded                           object
# Date_Autocoded                         object
# P_Symptom_Inferred                     object
# Root_Code_Secondary_Probability        object
# Root_Code_Tertiary_Probability         object
# Symptom_Code_Probability               object
# P_Symptom_Verified                     object
# P_Root_Code_Inferred_Secondary         object
# P_Root_Code_Inferred_Secondary_Desc    object
# P_Root_Code_Inferred_Tertiary          object
# P_Root_Code_Inferred_Tertiary_Desc     object
# P_Symptom_Code_Inferred                object
# P_Symptom_Code_Inferred_Desc           object
# P_Root_Code_Verified                   object
# P_Root_Code_Verified_Desc              object
# Is_Verified                            object
# Date_Verified                          object
# Master_Intervention_Key                object
# Is_Relevant                            object
# Is_Power_Pack_Intervention             object
# Model_URI_Root_Code_Secondary          object
# Model_URI_Root_Code_Tertiary           object
# Model_URI_Symptom                      object
# _Data_Source                           object
# _Time_Added                            object
# _Ingest_Timestamp                      object
# _UID                                   object
# dtype: object

# %%
# Fix column types
mock_df['Component_Mileage'] = mock_df['Component_Mileage'].astype(np.float32)
mock_df['Is_TIN'] = mock_df['Is_TIN'].astype('bool')
mock_df['Sum_Prim_Delay_Mins'] = mock_df['Sum_Prim_Delay_Mins'].astype(np.float64)
mock_df['Sum_Reactnry_Delay_Mins'] = mock_df['Sum_Reactnry_Delay_Mins'].astype(np.float64)
mock_df['Sum_Total_Delay_Mins'] = mock_df['Sum_Total_Delay_Mins'].astype(np.float64)
mock_df['Count_Full_Cancellations'] = mock_df['Count_Full_Cancellations'].astype(np.float64)
mock_df['Count_Part_Cancellations'] = mock_df['Count_Part_Cancellations'].astype(np.float64)
mock_df['Count_Total_Cancellations'] = mock_df['Count_Total_Cancellations'].astype(np.float32)
mock_df['Porterbrook_Asset'] = mock_df['Porterbrook_Asset'].astype(bool)
mock_df['Is_Autocoded'] = mock_df['Is_Autocoded'].astype(bool)
mock_df['Root_Code_Secondary_Probability'] = mock_df['Root_Code_Secondary_Probability'].astype(np.float32)
mock_df['Root_Code_Tertiary_Probability'] = mock_df['Root_Code_Tertiary_Probability'].astype(np.float32)
mock_df['Symptom_Code_Probability'] = mock_df['Symptom_Code_Probability'].astype(np.float32)
mock_df['Is_Verified'] = mock_df['Is_Verified'].astype(bool)
mock_df['Is_Power_Pack_Intervention'] = mock_df['Is_Power_Pack_Intervention'].astype(bool)
mock_df['_Time_Added'] = mock_df['_Time_Added'].astype(np.datetime64)
mock_df['_Ingest_Timestamp'] = mock_df['_Ingest_Timestamp'].astype(np.datetime64)

# %%
mock_df.dtypes
# Out:
# Depot                                          object
# R2_Depot                                       object
# TOC                                            object
# Railway_Period                                 object
# Date_Reported                                  object
# Date_Completed                                 object
# Date                                           object
# Fleet_Name                                     object
# Vehicle_Class                                  object
# Vehicle_Sub_Class                              object
# Unit                                           object
# Vehicle                                        object
# Intervention_ID                                object
# Intervention_Type                              object
# Intervention_Key                               object
# Component_Mileage                             float32
# Is_TIN                                           bool
# Intervention_Report                            object
# Intervention_Action                            object
# Work_Order_Type                                object
# Work_Order_Equipment                           object
# Work_Order_Status                              object
# System_Primary_Code                            object
# System_Primary_Code_Desc                       object
# System_Secondary_Code                          object
# System_Secondary_Code_Desc                     object
# Priority                                       object
# Warranty                                       object
# Location                                       object
# Sum_Prim_Delay_Mins                           float64
# Sum_Reactnry_Delay_Mins                       float64
# Sum_Total_Delay_Mins                          float64
# Count_Full_Cancellations                      float64
# Count_Part_Cancellations                      float64
# Count_Total_Cancellations                     float32
# Porterbrook_Asset                                bool
# Is_Autocoded                                     bool
# Date_Autocoded                                 object
# P_Symptom_Inferred                             object
# Root_Code_Secondary_Probability               float32
# Root_Code_Tertiary_Probability                float32
# Symptom_Code_Probability                      float32
# P_Symptom_Verified                             object
# P_Root_Code_Inferred_Secondary                 object
# P_Root_Code_Inferred_Secondary_Desc            object
# P_Root_Code_Inferred_Tertiary                  object
# P_Root_Code_Inferred_Tertiary_Desc             object
# P_Symptom_Code_Inferred                        object
# P_Symptom_Code_Inferred_Desc                   object
# P_Root_Code_Verified                           object
# P_Root_Code_Verified_Desc                      object
# Is_Verified                                      bool
# Date_Verified                                  object
# Master_Intervention_Key                        object
# Is_Relevant                                    object
# Is_Power_Pack_Intervention                       bool
# Model_URI_Root_Code_Secondary                  object
# Model_URI_Root_Code_Tertiary                   object
# Model_URI_Symptom                              object
# _Data_Source                                   object
# _Time_Added                            datetime64[ns]
# _Ingest_Timestamp                      datetime64[ns]
# _UID                                           object
# dtype: object

# %%
try: 
    # Append Data into Delta table
    write_deltalake(df, mock_df, mode="append") 
except Exception as e: 
    print(e)
# Out:
# Schema of data does not match table schema
# Table schema:
# Depot: string
# R2_Depot: string
# TOC: string
# Railway_Period: string
# Date_Reported: string
# Date_Completed: string
# Date: string
# Fleet_Name: string
# Vehicle_Class: string
# Vehicle_Sub_Class: string
# Unit: string
# Vehicle: string
# Intervention_ID: string
# Intervention_Type: string
# Intervention_Key: string
# Component_Mileage: float
# Is_TIN: bool
# Intervention_Report: string
# Intervention_Action: string
# Work_Order_Type: string
# Work_Order_Equipment: string
# Work_Order_Status: string
# System_Primary_Code: string
# System_Primary_Code_Desc: string
# System_Secondary_Code: string
# System_Secondary_Code_Desc: string
# Priority: string
# Warranty: string
# Location: string
# Sum_Prim_Delay_Mins: double
# Sum_Reactnry_Delay_Mins: double
# Sum_Total_Delay_Mins: double
# Count_Full_Cancellations: double
# Count_Part_Cancellations: double
# Count_Total_Cancellations: float
# Porterbrook_Asset: bool
# Is_Autocoded: bool
# Date_Autocoded: string
# P_Symptom_Inferred: string
# Root_Code_Secondary_Probability: float
# Root_Code_Tertiary_Probability: float
# Symptom_Code_Probability: float
# P_Symptom_Verified: string
# P_Root_Code_Inferred_Secondary: string
# P_Root_Code_Inferred_Secondary_Desc: string
# P_Root_Code_Inferred_Tertiary: string
# P_Root_Code_Inferred_Tertiary_Desc: string
# P_Symptom_Code_Inferred: string
# P_Symptom_Code_Inferred_Desc: string
# P_Root_Code_Verified: string
# P_Root_Code_Verified_Desc: string
# Is_Verified: bool
# Date_Verified: string
# Master_Intervention_Key: string
# Is_Relevant: bool
# Is_Power_Pack_Intervention: bool
# Model_URI_Root_Code_Secondary: string
# Model_URI_Root_Code_Tertiary: string
# Model_URI_Symptom: string
# _Data_Source: string
# _Time_Added: timestamp[us]
# _Ingest_Timestamp: timestamp[us]
# _UID: string
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 8783
# Data Schema:
# Depot: string
# R2_Depot: string
# TOC: string
# Railway_Period: string
# Date_Reported: date32[day]
# Date_Completed: date32[day]
# Date: date32[day]
# Fleet_Name: string
# Vehicle_Class: string
# Vehicle_Sub_Class: string
# Unit: string
# Vehicle: string
# Intervention_ID: string
# Intervention_Type: string
# Intervention_Key: string
# Component_Mileage: float
# Is_TIN: bool
# Intervention_Report: string
# Intervention_Action: string
# Work_Order_Type: string
# Work_Order_Equipment: string
# Work_Order_Status: string
# System_Primary_Code: string
# System_Primary_Code_Desc: string
# System_Secondary_Code: string
# System_Secondary_Code_Desc: string
# Priority: string
# Warranty: string
# Location: string
# Sum_Prim_Delay_Mins: int32
# Sum_Reactnry_Delay_Mins: int32
# Sum_Total_Delay_Mins: int32
# Count_Full_Cancellations: int32
# Count_Part_Cancellations: int32
# Count_Total_Cancellations: float
# Porterbrook_Asset: bool
# Is_Autocoded: bool
# Date_Autocoded: date32[day]
# P_Symptom_Inferred: string
# Root_Code_Secondary_Probability: float
# Root_Code_Tertiary_Probability: float
# Symptom_Code_Probability: float
# P_Symptom_Verified: string
# P_Root_Code_Inferred_Secondary: string
# P_Root_Code_Inferred_Secondary_Desc: string
# P_Root_Code_Inferred_Tertiary: string
# P_Root_Code_Inferred_Tertiary_Desc: string
# P_Symptom_Code_Inferred: string
# P_Symptom_Code_Inferred_Desc: string
# P_Root_Code_Verified: string
# P_Root_Code_Verified_Desc: string
# Is_Verified: bool
# Date_Verified: date32[day]
# Master_Intervention_Key: string
# Is_Relevant: bool
# Is_Power_Pack_Intervention: bool
# Model_URI_Root_Code_Secondary: string
# Model_URI_Root_Code_Tertiary: string
# Model_URI_Symptom: string
# _Data_Source: string
# _Time_Added: timestamp[us]
# _Ingest_Timestamp: timestamp[us]
# _UID: string
# c:\Users\StevenDas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyarrow\pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):

# %% [markdown]
# TESTING

# %%
from deltalake import DeltaTable
from pprint import pprint

if __name__ == '__main__':
    dt = DeltaTable('PATH_TO_DELTA_TABLE_IN_AZURE')
    print(f'Table version: {dt.version()}')
    for f in df.files():
        print(f' - {f}')

    df = dt.to_pyarrow_table().to_pandas()
    pprint(df)

# %%
import deltalake as dl
from deltalake.writer import write_deltalake
import pandas as pd
import numpy as np

# Define SAS token, storage account name, container name, and file path
sas_token = "<>"
storage_account_name = "mystorage"
container_name = "test-container"
csv_file = "test_delta/test_csv_data/products1.csv"
delta_path = "test_delta/light_delta_lake"
 
#csv url
csv_url = f"https://{storage_account_name}.dfs.core.windows.net/{container_name}/{csv_file}?{sas_token}"

# Construct the URL for the specified folder
protocol = "abfss"
delta_url = f"{protocol}://{container_name}@{storage_account_name}.dfs.core.windows.net/{delta_path}"
 
# Give SAS_TOKEN as storage option (apparently can also be set via ENV variable as well)
storage_options = {"SAS_TOKEN": f"{sas_token}"}
 
print(csv_url.replace(sas_token, "<SECRET>"))
print(' ')
print(str(storage_options).replace(sas_token, "<SECRET>"))
print(delta_url.replace(sas_token, "<SECRET>"))

# Read the Delta table from the storage account 
dt = dl.DeltaTable(delta_url, storage_options=storage_options)
 
# Print the schema and file URIs of the Delta table
print(dt.schema())
print(dt.file_uris())
 
# Print the history of the Delta table as a DataFrame
print(pd.DataFrame(dt.history()))
 
# Read the CSV file, modify the data, and convert it to a DataFrame
data = pd.read_csv(csv_url).assign(stars=lambda df: df['rating'].astype(np.int32)).drop(['description', 'ingredients'], axis=1).astype({'rating_count': np.int32})
data.head()
 
# Append the DataFrame to the Delta table
write_deltalake(table_or_uri=dt, data=data, mode="append")
 
# Print the updated file URIs and history of the Delta table
print(dt.file_uris())
print(pd.DataFrame(dt.history()))
